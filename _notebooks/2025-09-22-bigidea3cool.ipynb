# %% [markdown]
# ---
# layout: post
# title: teaching basics
# permalink: /bigidea3blog
# ---

# %% [markdown]
# <!--
# Paste this ENTIRE block into a Markdown (.md) file. Most Markdown engines (incl. GitHub/Jekyll) allow raw HTML/CSS/JS.
# Self‑contained: no external libs. Includes: parallax hero, scroll progress, sticky scrollytelling, reveal animations,
# inline SVG characters, mini videos (placeholders), interactive complexity visualizer, and a quick review game.
# Replace any image/video src with your own files when you publish.
# -->
#
# <div id="csp-app" class="csp-root">
#   <style>
#     :root{
#       --bg:#0b0c0f; --panel:#12141a; --ink:#f6f7fb; --muted:#c9cbd4; --accent:#7bc6ff; --accent2:#83ffb4; --warn:#ffc773;
#       --shadow:0 18px 40px rgba(0,0,0,.35); --radius:22px; --w:min(1100px,92vw);
#     }
#     @media(prefers-color-scheme:light){:root{--bg:#f7f8fb;--panel:#ffffff;--ink:#0b0c0f;--muted:#394150;--shadow:0 10px 26px rgba(0,0,0,.12)}}
#     *{box-sizing:border-box}
#     body{margin:0}
#     .csp-root{color:var(--ink); background:radial-gradient(1200px 600px at 80% -10%, #1b1f2a 10%, transparent 60%), var(--bg); font:16px ui-sans-serif,system-ui,-apple-system,Segoe UI,Roboto,Arial; line-height:1.55; overflow-x:hidden}
#     .csp-progress{position:fixed; inset:0 0 auto 0; height:4px; background:linear-gradient(90deg,var(--accent),var(--accent2)); transform:scaleX(0); transform-origin:left; z-index:9999}
#     .wrap{width:var(--w); margin:0 auto}
#
#     /* BLOG FULL‑BLEED FIX — prevents clipping inside Markdown/Jekyll containers */
#     :where(.markdown-body,.post-content,.post,.page-content) #csp-app,
#     #csp-app.fullbleed{
#       /* stretch to viewport width even if parent is a centered column */
#       --bleed: calc(50vw - 50%);
#       width:auto; max-width:none;
#       margin-left: calc(-1 * var(--bleed));
#       margin-right: calc(-1 * var(--bleed));
#     }
#     /* allow absolutely-positioned backgrounds to render outside the article column */
#     :where(.markdown-body,.post-content,.post,.page-content){ overflow: visible !important; }
#
#     /* HERO */
#     header.csp-hero{position:relative; min-height:92vh; display:grid; place-items:center; overflow:hidden}
#     .hero-bg{position:absolute; inset:-10% -10% -10% -10%; background:
#       radial-gradient(1200px 700px at 20% -10%, rgba(131,255,180,.25), transparent 60%),
#       radial-gradient(1200px 700px at 80% 110%, rgba(123,198,255,.25), transparent 60%),
#       url('data:image/svg+xml;utf8,<svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 1200 800"><defs><linearGradient id="g" x1="0" x2="1"><stop offset="0" stop-color="%230b0c0f"/><stop offset="1" stop-color="%23161a22"/></linearGradient></defs><rect width="1200" height="800" fill="url(%23g)"/><g fill="none" stroke="%2346a4ff" stroke-opacity="0.18"><circle cx="300" cy="400" r="240"/><circle cx="900" cy="460" r="260"/></g></svg>') center/cover no-repeat; will-change:transform; filter:saturate(105%) contrast(105%)}
#     header.csp-hero::after{content:""; position:absolute; inset:0; background:linear-gradient(180deg, rgba(0,0,0,.35), transparent 40%, rgba(0,0,0,.55))}
#     .hero-inner{position:relative; text-align:center; padding:22vh 0}
#     .kicker{letter-spacing:.18em; text-transform:uppercase; color:var(--muted)}
#     h1{font-weight:800; font-size:clamp(32px,6vw,72px); margin:.35em 0}
#     .sub{color:var(--muted); font-size:clamp(16px,2.2vw,22px); max-width:60ch; margin:0 auto 24px}
#     .cta-row{display:flex; gap:12px; justify-content:center; flex-wrap:wrap; margin-top:20px}
#     .btn{appearance:none; border:1px solid transparent; background:var(--ink); color:var(--bg); padding:12px 18px; border-radius:999px; font-weight:700; cursor:pointer; box-shadow:var(--shadow); transition:.25s transform}
#     .btn:hover{transform:translateY(-2px)}
#     .btn.ghost{background:transparent; color:var(--ink); border-color:rgba(255,255,255,.25)}
#
#     /* REVEAL */
#     .reveal{opacity:0; transform:translateY(18px); transition:opacity .6s ease, transform .6s ease}
#     .reveal.in{opacity:1; transform:none}
#
#     /* PANELS */
#     section{margin:clamp(48px,10vh,140px) 0}
#     .panel{background:linear-gradient(180deg, rgba(255,255,255,.06), rgba(255,255,255,.02)); border:1px solid rgba(255,255,255,.08); border-radius:var(--radius); padding:clamp(16px,3vw,28px); box-shadow:var(--shadow)}
#
#     /* STICKY SCROLLY */
#     .scrolly{display:grid; grid-template-columns: 1.06fr .94fr; gap:clamp(16px,3vw,28px)}
#     .steps{position:relative}
#     .step{padding:16px 18px; border-radius:16px; margin:12px 0; border:1px solid rgba(255,255,255,.08); background:linear-gradient(180deg, rgba(255,255,255,.06), rgba(255,255,255,0))}
#     .step.is-active{outline:2px solid var(--accent); background:linear-gradient(180deg, rgba(123,198,255,.18), rgba(123,198,255,.05))}
#     .stage{position:sticky; top:12vh}
#     .device{position:relative; overflow:hidden; border-radius:26px; border:1px solid rgba(255,255,255,.1); box-shadow:var(--shadow)}
#     .device::after{content:""; position:absolute; inset:0; box-shadow: inset 0 0 0 2px rgba(255,255,255,.04); pointer-events:none; border-radius:26px}
#     .device img, .device video{display:block; width:100%; height:auto}
#     .device .caption{position:absolute; left:0; right:0; bottom:0; padding:12px 16px; color:#fff; background:linear-gradient(180deg, transparent, rgba(0,0,0,.55)); font-size:14px}
#
#     /* STATS */
#     .stats{display:grid; grid-template-columns: repeat(4, 1fr); gap: clamp(12px, 2vw, 20px)}
#     .stat{padding:18px; border-radius:16px; background:linear-gradient(180deg, rgba(255,255,255,.06), rgba(255,255,255,.01)); border:1px solid rgba(255,255,255,.08); text-align:center}
#     .stat .num{font-weight:900; font-size: clamp(22px, 3.6vw, 42px)}
#     .stat .label{color:var(--muted)}
#
#     /* TABLE */
#     .table-elevated{width:100%; border-collapse:separate; border-spacing:0; overflow:hidden; border-radius:16px; background:rgba(255,255,255,.03); box-shadow:var(--shadow)}
#     .table-elevated thead th{position:sticky; top:0; z-index:2; background:linear-gradient(180deg, rgba(255,255,255,.12), rgba(255,255,255,.06)); text-align:left; font-weight:800; letter-spacing:.2px}
#     .table-elevated th, .table-elevated td{padding:14px 16px; border-bottom:1px solid rgba(255,255,255,.12); font-size:clamp(14px,1.4vw,16px)}
#     .table-elevated tbody tr:nth-child(odd){background:rgba(255,255,255,.02)}
#     .table-elevated tbody tr:hover{background:rgba(123,198,255,.08)}
#     .table-elevated tbody td{color:var(--ink)}
#
#     /* CHARACTERS (SVG sprites) */ (SVG sprites) */
#     .chars{display:flex; gap:14px; align-items:center}
#     .chip{display:inline-flex; align-items:center; gap:8px; padding:8px 12px; border-radius:999px; border:1px solid rgba(255,255,255,.15); background:rgba(255,255,255,.05)}
#     .blink{animation: blink 2s infinite}
#     @keyframes blink{0%,90%,100%{opacity:1}95%{opacity:.1}}
#
#     /* VISUALIZER */
#     .viz{display:grid; gap:14px}
#     .bar{height:16px; border-radius:999px; background:linear-gradient(90deg,var(--accent),var(--accent2)); width:10%}
#     .bar.warn{background:linear-gradient(90deg,#ff9d73, #ff5c84)}
#     .viz-controls{display:flex; gap:10px; align-items:center; flex-wrap:wrap}
#     .code{font: 14px ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace; background:rgba(0,0,0,.35); border:1px solid rgba(255,255,255,.12); border-radius:12px; padding:8px 10px; overflow:auto}
#
#     /* QUIZ */
#     .quiz{display:grid; gap:10px}
#     .opt{padding:12px; border:1px solid rgba(255,255,255,.18); border-radius:12px; cursor:pointer; background:rgba(255,255,255,.04)}
#     .opt[aria-checked="true"]{outline:2px solid var(--accent)}
#     .opt.correct{outline:2px solid var(--accent2)}
#     .opt.wrong{outline:2px solid #ff5c84}
#     .toast{margin-top:10px; color:var(--muted)}
#
#     footer{padding:48px 0 80px; color:var(--muted); text-align:center}
#
#     @media(max-width:920px){.scrolly{grid-template-columns:1fr}.stats{grid-template-columns:repeat(2,1fr)}}
#   /* === Enhancements: motion, pop, particles, lightbox, toc === */
#     @keyframes popIn{0%{opacity:0; transform:translateY(24px) scale(.95)}70%{opacity:1}100%{transform:none}}
#     .reveal.in{animation: popIn .7s cubic-bezier(.2,.7,.2,1) both}
#     .pop:hover{transform: translateY(-3px) scale(1.02)}
#
#     /* Magnetic buttons */
#     .btn.magnetic{transition: transform .15s ease-out}
#
#     /* Smooth anchor scroll */
#     html:focus-within{scroll-behavior:smooth}
#
#     /* Particles canvas */
#     #particles{position:fixed; inset:0; pointer-events:none; z-index:0; opacity:.4}
#
#     /* Elevate hero on top of particles */
#     header.csp-hero, main, footer{position:relative; z-index:1}
#
#     /* Sticky TOC */
#     .toc{position:sticky; top:12px; background:linear-gradient(180deg, rgba(255,255,255,.06), rgba(255,255,255,.02)); border:1px solid rgba(255,255,255,.08); border-radius:14px; padding:10px 12px; box-shadow:var(--shadow); display:flex; gap:10px; flex-wrap:wrap}
#     .toc a{color:var(--muted); text-decoration:none; padding:6px 10px; border-radius:999px; border:1px solid rgba(255,255,255,.12)}
#     .toc a.active{color:var(--ink); border-color:var(--accent)}
#
#     /* Lightbox */
#     #lightbox{position:fixed; inset:0; background:rgba(0,0,0,.7); display:none; align-items:center; justify-content:center; z-index:9998}
#     #lightbox.show{display:flex}
#     #lightbox .frame{max-width:min(94vw,1100px); max-height:90vh; border-radius:14px; overflow:hidden; box-shadow:var(--shadow); background:#000}
#     #lightbox .frame img, #lightbox .frame video{width:100%; height:auto; display:block}
#
#     /* Copy badge */
#     .copy-btn{position:absolute; right:10px; top:10px; font:13px ui-monospace,monospace; padding:6px 10px; border-radius:10px; border:1px solid rgba(255,255,255,.35); background:linear-gradient(180deg, rgba(255,255,255,.22), rgba(255,255,255,.06)); color:var(--ink); box-shadow:var(--shadow); opacity:.98}
#     .copy-btn:hover{transform:translateY(-1px);}
#     .code.wraprel{position:relative}
#
#     /* Dolphin pod (fixed, non-overlapping sidebar animation) */
#     #dolphin-pod{position:fixed; right:18px; top:18vh; width:140px; height:64vh; pointer-events:none; z-index:2; display:flex; align-items:flex-start; justify-content:center; gap:8px; opacity:0; transform:translateX(40px)}
#     #dolphin-pod.show{opacity:1; transform:none; transition:opacity .8s ease, transform .8s cubic-bezier(.2,.7,.2,1)}
#     .dolphin{width:120px; filter:drop-shadow(0 6px 18px rgba(0,0,0,.35))}
#     .dolphin svg{display:block; width:100%; height:auto}
#     .swim{animation: swimY var(--dur,9s) linear infinite, swimX 6s ease-in-out infinite alternate}
#     @keyframes swimY{0%{transform:translateY(-5%)}100%{transform:translateY(105%)}}
#     @keyframes swimX{0%{transform:translateX(0)}100%{transform:translateX(-12px)}}
#
#     /* Reduced motion */
#     @media (prefers-reduced-motion: reduce){
#       *{animation:none!important; transition:none!important}
#       #dolphin-pod{display:none}
#     }
#     /* Reduced motion */
#     @media (prefers-reduced-motion: reduce){
#       *{animation:none!important; transition:none!important}
#     }
#   </style>
#
#   <div class="csp-progress" id="csp-progress"></div>
#
#   <!-- HERO -->
#   <header class="csp-hero" role="banner">
#     <div class="hero-bg" id="hero-bg"></div>
#     <div class="hero-inner wrap">
#       <div class="kicker">AP CSP • Big Idea 3</div>
#       <h1>📘 Problems, Algorithms, and Efficiency</h1>
#       <p class="sub">Apple‑style, scroll‑driven lesson with animations, mini videos, and interactive widgets — all in a single Markdown‑friendly file.</p>
#       <div class="cta-row">
#         <a href="#s-problem" class="btn">Start Lesson</a>
#         <button class="btn ghost" id="jump-demo">See Demo</button>
#       </div>
#       <div class="chars" style="justify-content:center; margin-top:16px">
#         <span class="chip"><svg width="20" height="20" viewBox="0 0 24 24" fill="none"><circle cx="12" cy="12" r="10" fill="#7bc6ff"/><circle class="blink" cx="9" cy="10" r="1.5" fill="#0b0c0f"/><circle cx="15" cy="10" r="1.5" fill="#0b0c0f"/><rect x="8" y="14" width="8" height="2" rx="1" fill="#0b0c0f"/></svg> Algo‑Bot</span>
#         <span class="chip"><svg width="20" height="20" viewBox="0 0 24 24" fill="none"><rect x="2" y="4" width="20" height="16" rx="4" fill="#83ffb4"/><circle cx="9" cy="12" r="2" fill="#0b0c0f"/><circle cx="15" cy="12" r="2" fill="#0b0c0f"/></svg> Heuri‑Kid</span>
#       </div>
#     </div>
#   </header>
#
#   <nav class="wrap toc reveal" aria-label="Lesson sections">
#       <a href="#s-problem">Problems</a>
#       <a href="#s-reason">Reasonable vs Unreasonable</a>
#       <a href="#s-table">Examples</a>
#       <a href="#s-heur">Heuristics & TSP</a>
#       <a href="#s-quiz">Quick Check</a>
#       <a href="#s-game">Game</a>
#     </nav>
#   <main>
#     <!-- STATS PEEK -->
#     <section class="wrap reveal" id="s-peek">
#       <div class="panel">
#         <div class="stats" aria-hidden="true">
#           <div class="stat"><div class="num">O(1)</div><div class="label">constant</div></div>
#           <div class="stat"><div class="num">O(n)</div><div class="label">linear</div></div>
#           <div class="stat"><div class="num">O(n²)</div><div class="label">quadratic</div></div>
#           <div class="stat"><div class="num">O(2ⁿ)</div><div class="label">exponential</div></div>
#         </div>
#       </div>
#     </section>
#
#     <!-- SCROLLY SECTION: Core Concepts -->
#     <section class="wrap scrolly" id="s-problem">
#       <div class="steps">
#         <div class="step" data-caption="Problems define goals; algorithms are the recipes to reach them.">
#           <h2>❓ What is a Problem?</h2>
#           <p>A <strong>problem</strong> is a general task that we want an algorithm to solve. <em>Example:</em> Sorting is a problem (putting numbers in order).</p>
#         </div>
#         <div class="step" data-caption="Each instance is one concrete input you can actually run.">
#           <h2>🧩 What is an Instance?</h2>
#           <p>An <strong>instance</strong> is a specific case of a problem with actual input values. <em>Example:</em> Sorting <code>(2,3,1,7)</code> is one instance of the sorting problem.</p>
#         </div>
#         <div class="step" data-caption="Different problem types lead to different strategies.">
#           <h2>🗂️ Types of Problems</h2>
#           <ul>
#             <li><strong>✅ Decision:</strong> Yes/No answer. <em>Example:</em> “Is there a path from A to B?”</li>
#             <li><strong>🏆 Optimization:</strong> Find the <em>best</em> solution. <em>Example:</em> shortest path from A to B.</li>
#           </ul>
#         </div>
#         <div class="step" data-caption="Efficiency asks how cost grows as inputs grow.">
#           <h2>⏱️ Measuring Efficiency</h2>
#           <p>Efficiency tells us how <strong>fast an algorithm grows</strong> as the input size increases. We estimate by counting <strong>operations</strong>, not wall‑clock time.</p>
#         </div>
#       </div>
#       <div class="stage">
#         <div class="device">
#           <video muted playsinline loop poster="data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 800 500'><rect width='800' height='500' fill='%23161a22'/><text x='50%' y='50%' fill='%23c9cbd4' font-size='24' text-anchor='middle' dominant-baseline='middle'>Drop your demo.mp4 here</text></svg>" id="demoVid">
#             <!-- Replace src with your local video file -->
#             <source src="" type="video/mp4" />
#           </video>
#           <div class="caption" id="stage-cap">Problems define goals; algorithms are the recipes to reach them.</div>
#         </div>
#       </div>
#     </section>
#
#     <!-- Reasonable vs Unreasonable -->
#     <section class="wrap reveal" id="s-reason">
#       <div class="panel">
#         <h2>⚡ Reasonable vs. 🐢 Unreasonable Time</h2>
#         <div class="chars" style="margin:10px 0 14px">
#           <span class="chip">Algo‑Bot: <em>“Can we finish before lunch?”</em></span>
#           <span class="chip">Heuri‑Kid: <em>“Only if it’s polynomial!”</em></span>
#         </div>
#         <div class="viz">
#           <div class="viz-controls">
#             <label for="n">Input size n:</label>
#             <input id="n" type="range" min="1" max="12" value="5"/>
#             <span id="nVal">5</span>
#           </div>
#           <div>
#             <div>Algorithm 1 (Linear → 5n): <span id="v1">25</span> steps</div>
#             <div class="bar" id="b1"></div>
#           </div>
#           <div>
#             <div>Algorithm 2 (Exponential → 3ⁿ): <span id="v2">243</span> steps</div>
#             <div class="bar warn" id="b2"></div>
#           </div>
#           <div>
#             <div>Algorithm 3 (Quadratic → 4n²): <span id="v3">100</span> steps</div>
#             <div class="bar" id="b3"></div>
#           </div>
#           <div>
#             <div>Algorithm 4 (Factorial → n!): <span id="v4">120</span> steps</div>
#             <div class="bar warn" id="b4"></div>
#           </div>
#           <div class="code" aria-label="Big-O cheat">
#             <strong>Reasonable:</strong> O(1), O(log n), O(n), O(n log n), O(n²*)
#             &nbsp;&nbsp;|&nbsp;&nbsp; <strong>Unreasonable:</strong> O(2ⁿ), O(n!)
#             <br/><small>*Quadratic can be okay for small/medium n.</small>
#           </div>
#         </div>
#       </div>
#     </section>
#
#     <!-- Table Example -->
#     <section class="wrap reveal" id="s-table">
#       <div class="panel">
#         <h2>📊 Example: Algorithms and Input Size</h2>
#         <table class="table-elevated">
#           <thead><tr><th>Input Size (n)</th><th>Algorithm 1 Steps</th><th>Algorithm 2 Steps</th><th>Algorithm 3 Steps</th><th>Algorithm 4 Steps</th></tr></thead>
#           <tbody id="algTable"></tbody>
#         </table>
#         <details style="margin-top:10px"><summary>🔍 Breaking Down Each Algorithm</summary>
#           <ul>
#             <li><strong>Algorithm 1 (Linear → 5n)</strong> — scan a list once. For n=5 → 25 steps. Efficiency: <code>O(n)</code> → ✅ reasonable.</li>
#             <li><strong>Algorithm 2 (Exponential → 3ⁿ)</strong> — brute‑force passwords with 3 chars each. For n=5 → 243 steps. Efficiency: <code>O(3ⁿ)</code> → 🚫 not reasonable.</li>
#             <li><strong>Algorithm 3 (Quadratic → 4n²)</strong> — compare every pair. For n=5 → 100 steps. Efficiency: <code>O(n²)</code> → ⚠️ okay for small/medium n.</li>
#             <li><strong>Algorithm 4 (Factorial → n!)</strong> — try all orderings. For n=5 → 120 steps. Efficiency: <code>O(n!)</code> → ❌ not reasonable.</li>
#           </ul>
#         </details>
#       </div>
#     </section>
#
#     <!-- Heuristics + TSP -->
#     <section class="wrap scrolly" id="s-heur">
#       <div class="steps">
#         <div class="step" data-caption="Exact search explodes with cities. Heuristics give usable routes fast.">
#           <h2>🛠️ What is a Heuristic Approach?</h2>
#           <p>A heuristic finds a <strong>good‑enough</strong> solution efficiently. It’s a smart shortcut, not guaranteed optimal, but practical when exact is too slow.</p>
#         </div>
#         <div class="step" data-caption="TSP: visit each city once, return to start — minimize distance.">
#           <h2>🧳🌍 Traveling Salesperson Problem (TSP)</h2>
#           <ul>
#             <li>Visit all cities once, return to start.</li>
#             <li>Goal: <strong>shortest total distance</strong>.</li>
#             <li>Routes grow <strong>factorially</strong>: 4 cities → 6; 10 → 362,880; 20 → ~10¹⁷.</li>
#           </ul>
#         </div>
#         <div class="step" data-caption="Nearest‑Neighbor: always pick the closest unvisited city.">
#           <h2>Why Heuristics Help</h2>
#           <p><strong>Nearest Neighbor</strong> example: from your current city, go to the closest unvisited city. Fast, simple, often good.</p>
#         </div>
#         <div class="step" data-caption="Scheduling is a constraint jungle — heuristics shine here.">
#           <h2>📚 Example: High School Scheduling</h2>
#           <p><strong>Best use of a heuristic?</strong> <em>Creating the master schedule for a high school</em> — complex & constrained → heuristics fit. Searching prices, GPAs, or password generation don’t need heuristics.</p>
#         </div>
#       </div>
#       <div class="stage">
#         <div class="device">
#           <img alt="TSP cities" id="tspImg" src="data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 800 500'><rect width='800' height='500' fill='%23161a22'/><g fill='%2383ffb4'><circle cx='120' cy='120' r='6'/><circle cx='680' cy='140' r='6'/><circle cx='420' cy='320' r='6'/><circle cx='260' cy='420' r='6'/><circle cx='720' cy='380' r='6'/></g><path d='M120 120 L420 320 L260 420 L680 140 L720 380 Z' stroke='%237bc6ff' stroke-width='2' fill='none'/></svg>"/>
#           <div class="caption" id="heur-cap">Exact search explodes with cities. Heuristics give usable routes fast.</div>
#         </div>
#       </div>
#     </section>
#
#     <!-- Quick Quiz -->
#     <section class="wrap reveal" id="s-quiz">
#       <div class="panel">
#         <h2>🧠 Quick Check</h2>
#         <div class="quiz" role="radiogroup" aria-labelledby="q1lab">
#           <div id="q1lab" class="muted">In which situation is a heuristic most useful?</div>
#           <div class="opt" data-correct="false">A. Searching a list of prices for the smallest value</div>
#           <div class="opt" data-correct="true">B. Creating the master schedule for a high school</div>
#           <div class="opt" data-correct="false">C. Calculating GPA for all students</div>
#           <div class="opt" data-correct="false">D. Generating passwords</div>
#           <div class="toast" id="quiz-toast">Choose an option.</div>
#         </div>
#       </div>
#     </section>
#
#     <!-- Mini Review Game -->
#     <section class="wrap reveal" id="s-game">
#       <div class="panel">
#         <h2>🎲 Mini Review Game: “Climb the Big‑O”</h2>
#         <p>Roll to move. Land on <strong>green</strong> (good time complexity) → climb ahead. Land on <strong>pink</strong> (bad complexity) → slide back.</p>
#         <canvas id="board" width="800" height="280" style="width:100%;max-width:800px;border-radius:16px;border:1px solid rgba(255,255,255,.12);background:linear-gradient(180deg, rgba(255,255,255,.03), rgba(255,255,255,.01))"></canvas>
#         <div class="cta-row" style="justify-content:flex-start"><button class="btn" id="roll">Roll 🎲</button><span id="status" style="margin-left:12px;color:var(--muted)">You are at start.</span></div>
#       </div>
#     </section>
#       <!-- Glossary -->
#     <section class="wrap reveal" id="s-glossary">
#       <div class="panel">
#         <h2>📖 Quick Glossary</h2>
#         <details open><summary><strong>Problem</strong></summary><p>A general task an algorithm aims to solve.</p></details>
#         <details><summary><strong>Instance</strong></summary><p>A specific input of a problem (e.g., sorting (2,3,1,7)).</p></details>
#         <details><summary><strong>Decision Problem</strong></summary><p>Yes/No answer (e.g., path exists?).</p></details>
#         <details><summary><strong>Optimization Problem</strong></summary><p>Find the best solution (e.g., shortest path).</p></details>
#         <details><summary><strong>Efficiency / Big‑O</strong></summary><p>How runtime/space grows with input size (O(1), O(n), O(n log n), …).</p></details>
#         <details><summary><strong>Heuristic</strong></summary><p>Rule‑of‑thumb method that finds good‑enough solutions quickly.</p></details>
#         <details><summary><strong>TSP</strong></summary><p>Visit each city once and return to start with minimal total distance.</p></details>
#       </div>
#     </section>
#   </main>
#
#   <footer>
#     Built with 💙 for interactive CSP learning. Replace images/videos as needed; everything runs in a single Markdown file.
#   </footer>
#   <!-- global particles + lightbox -->
#   <canvas id="particles"></canvas>
#   <div id="lightbox" role="dialog" aria-modal="true"><div class="frame" id="lightbox-frame"></div></div>
#   <div id="dolphin-pod" aria-hidden="true"></div>
#
#   <script>
#     // Progress bar
#     const prog = document.getElementById('csp-progress');
#     const onScroll = () => { const p = window.scrollY / (document.body.scrollHeight - innerHeight); prog.style.transform = `scaleX(${p})`; }; window.addEventListener('scroll', onScroll);
#
#     // Parallax hero background
#     const hero = document.getElementById('hero-bg');
#     window.addEventListener('scroll', () => { const y = window.scrollY * 0.15; hero.style.transform = `translateY(${y}px)`; });
#
#     // Reveal on scroll
#     const io = new IntersectionObserver((ents)=>ents.forEach(e=>e.target.classList.toggle('in', e.isIntersecting)),{threshold:.15});
#     document.querySelectorAll('.reveal').forEach(el=>io.observe(el));
#
#     // Sticky scrollytelling captions
#     function setupScrolly(rootId, capId){
#       const root = document.querySelector(rootId); if(!root) return; const steps = root.querySelectorAll('.step'); const cap = root.querySelector(capId);
#       const obs = new IntersectionObserver((ents)=>{
#         ents.forEach(en=>{ if(en.isIntersecting){ steps.forEach(s=>s.classList.remove('is-active')); en.target.classList.add('is-active'); cap.textContent = en.target.dataset.caption; }});
#       },{rootMargin:'-40% 0px -55% 0px', threshold:0}); steps.forEach(s=>obs.observe(s));
#     }
#     setupScrolly('#s-problem', '#stage-cap');
#     setupScrolly('#s-heur', '#heur-cap');
#
#     // Demo video auto play on click
#     const demoVid = document.getElementById('demoVid');
#     document.getElementById('jump-demo').addEventListener('click',()=>{ demoVid && demoVid.play && demoVid.play(); window.location.hash = '#s-problem'; });
#
#     // Complexity visualizer
#     const nRange = document.getElementById('n');
#     const nVal = document.getElementById('nVal');
#     const bars = { b1:document.getElementById('b1'), b2:document.getElementById('b2'), b3:document.getElementById('b3'), b4:document.getElementById('b4') };
#     const vals = { v1:document.getElementById('v1'), v2:document.getElementById('v2'), v3:document.getElementById('v3'), v4:document.getElementById('v4') };
#     function fact(k){ let r=1n; for(let i=2n;i<=BigInt(k);i++) r*=i; return r; }
#     function updateViz(){ const n = +nRange.value; nVal.textContent=n; const v1=5*n; const v2= Math.trunc(3**n); const v3=4*n*n; const v4= Number(fact(n));
#       vals.v1.textContent=v1; vals.v2.textContent=v2.toLocaleString(); vals.v3.textContent=v3; vals.v4.textContent=v4.toLocaleString();
#       const max = Math.max(v1, v2, v3, Math.min(v4, 100000));
#       bars.b1.style.width = Math.max(8, v1/max*100) + '%';
#       bars.b2.style.width = Math.max(8, v2/max*100) + '%';
#       bars.b3.style.width = Math.max(8, v3/max*100) + '%';
#       bars.b4.style.width = Math.max(8, Math.min(v4,100000)/max*100) + '%';
#     }
#     nRange.addEventListener('input', updateViz); updateViz();
#
#     // Build the algorithm table rows dynamically for n=1..5
#     const tbody = document.getElementById('algTable');
#     const data = [1,2,3,4,5].map(n=>({ n, a1:5*n, a2:3**n, a3:4*n*n, a4:(()=>{let r=1; for(let i=2;i<=n;i++) r*=i; return r;})() }));
#     tbody.innerHTML = data.map(r=>`<tr><td>${r.n}</td><td>${r.a1}</td><td>${r.a2}</td><td>${r.a3}</td><td>${r.a4}</td></tr>`).join('');
#
#     // Dolphin pod — animated, fixed to the side
#     (function(){
#       const pod = document.getElementById('dolphin-pod'); if(!pod) return;
#       function icon(fill){return `<?xml version='1.0'?><svg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 180 80'>
#         <defs><linearGradient id='g' x1='0' x2='1'><stop offset='0' stop-color='${fill}'/><stop offset='1' stop-color='${fill}AA'/></linearGradient></defs>
#         <g fill='url(%23g)'><path d='M10 45c20-25 55-35 95-26 20 5 36 17 55 34-18-2-31 2-41 8-8 5-14 6-23 5-9-1-18-4-27-10-8 5-19 5-31 1-7-2-16-7-28-12z'/>
#         <circle cx='62' cy='34' r='3' fill='#0b0c0f'/></g></svg>`}
#       const colors=['#9fe3ff','#83ffb4','#b6b3ff'];
#       for(let i=0;i<3;i++){
#         const d=document.createElement('div'); d.className='dolphin swim'; d.style.setProperty('--dur', `${8+i*1.8}s`);
#         d.innerHTML=icon(colors[i%colors.length]); d.style.animationDelay=`-${i*2.3}s`; pod.appendChild(d);
#       }
#       requestAnimationFrame(()=> pod.classList.add('show'));
#     })();
#
#     // Quiz logic
#     const quiz = document.querySelector('#s-quiz .quiz'); const toast = document.getElementById('quiz-toast');
#     quiz.querySelectorAll('.opt').forEach(opt=>{
#       opt.addEventListener('click', ()=>{
#         quiz.querySelectorAll('.opt').forEach(o=>{o.setAttribute('aria-checked','false'); o.classList.remove('correct','wrong');});
#         opt.setAttribute('aria-checked','true');
#         if(opt.dataset.correct==='true'){ opt.classList.add('correct'); toast.textContent='Correct! Scheduling is complex and constrained — heuristics help.'; }
#         else { opt.classList.add('wrong'); toast.textContent='Not this one. Exact methods are fast enough here — no heuristic needed.'; }
#       });
#     });
#
#     // Mini “Climb the Big‑O” game
#     const board = document.getElementById('board'); const ctx = board.getContext('2d');
#     const tiles = 16; const w = board.width; const h = board.height; const pad = 24; const cw = (w-2*pad)/tiles; const ch = h-2*pad;
#     const ladders = {2:6, 5:11}; // good complexities boost
#     const snakes  = {9:4, 13:7}; // bad complexities punish
#     let pos = 0;
#     function drawBoard(){ ctx.clearRect(0,0,w,h); ctx.save(); ctx.translate(pad,pad);
#       for(let i=0;i<tiles;i++){
#         const x = i*cw; const color = (i%2? '#2d3342':'#222838'); ctx.fillStyle=color; ctx.fillRect(x,0,cw,ch);
#         // labels
#         ctx.fillStyle='#c9cbd4'; ctx.font='12px ui-sans-serif'; ctx.fillText(i.toString(), x+6, ch-8);
#       }
#       // ladders & snakes
#       function arrow(from,to,clr){ const fx=from*cw+cw/2, tx=to*cw+cw/2; ctx.strokeStyle=clr; ctx.lineWidth=4; ctx.beginPath(); ctx.moveTo(fx, ch*0.65); ctx.lineTo(tx, ch*0.35); ctx.stroke(); }
#       arrow(2,6,'#83ffb4'); arrow(5,11,'#83ffb4'); arrow(13,7,'#ff5c84'); arrow(9,4,'#ff5c84');
#       // player
#       const px = pos*cw+cw/2, py = ch*0.8; ctx.fillStyle='#7bc6ff'; ctx.beginPath(); ctx.arc(px,py,12,0,Math.PI*2); ctx.fill();
#       ctx.restore();
#     }
#     function moveBy(d){ let next = Math.min(tiles-1, pos + d); let msg = `Moved ${d}.`;
#       if(ladders[next]!=null){ msg += ' Nice! Climbed ahead.'; next = ladders[next]; }
#       if(snakes[next]!=null){ msg += ' Ouch! Slid back.'; next = snakes[next]; }
#       pos = next; drawBoard(); document.getElementById('status').textContent = `You are on tile ${pos}/${tiles-1}. ${msg}`; if(pos===tiles-1) document.getElementById('status').textContent = '🎉 You win!';
#     }
#     drawBoard();
#     document.getElementById('roll').addEventListener('click', ()=> moveBy(1+Math.floor(Math.random()*3)));
#       // Magnetic buttons effect
#     document.querySelectorAll('.btn.magnetic, .btn').forEach(btn=>{
#       const bounds = ()=>btn.getBoundingClientRect();
#       btn.addEventListener('mousemove', e=>{ const b=bounds(); const x=(e.clientX-b.left-b.width/2)/8; const y=(e.clientY-b.top-b.height/2)/8; btn.style.transform=`translate(${x}px, ${y}px)`; });
#       btn.addEventListener('mouseleave', ()=> btn.style.transform='');
#     });
#
#     // Typewriter for hero subline
#     (function(){ const el=document.querySelector('.sub'); if(!el) return; const text=el.textContent.trim(); el.textContent=''; let i=0; const t=()=>{ if(i<=text.length){ el.textContent=text.slice(0,i++); setTimeout(t, 14); } }; t(); })();
#
#     // Particles
#     (function(){ const c=document.getElementById('particles'); if(!c) return; const ctx=c.getContext('2d'); let W,H; const R=()=>{W=c.width=innerWidth; H=c.height=innerHeight}; R(); addEventListener('resize',R);
#       const dots=Array.from({length:70},()=>({x:Math.random()*W,y:Math.random()*H,vx:(Math.random()-.5)*0.4,vy:(Math.random()-.5)*0.4,r:1+Math.random()*2}));
#       function step(){ ctx.clearRect(0,0,W,H); ctx.globalAlpha=.6; dots.forEach(d=>{ d.x+=d.vx; d.y+=d.vy; if(d.x<0||d.x>W) d.vx*=-1; if(d.y<0||d.y>H) d.vy*=-1; ctx.beginPath(); ctx.arc(d.x,d.y,d.r,0,Math.PI*2); ctx.fillStyle='rgba(123,198,255,.35)'; ctx.fill(); }); requestAnimationFrame(step);} step(); })();
#
#     // Lightbox for images/videos with data-lightbox
#     document.querySelectorAll('[data-lightbox] img, [data-lightbox] video, .device img, .device video').forEach(el=>{
#       el.style.cursor='zoom-in';
#       el.addEventListener('click',()=>{
#         const lb=document.getElementById('lightbox'); const frame=document.getElementById('lightbox-frame');
#         frame.innerHTML=''; const clone=el.cloneNode(true); clone.removeAttribute('id'); clone.removeAttribute('style'); if(clone.tagName==='VIDEO'){ clone.controls=true; clone.muted=false; }
#         frame.appendChild(clone); lb.classList.add('show');
#       });
#     });
#     document.getElementById('lightbox').addEventListener('click',e=>{ if(e.target.id==='lightbox') e.currentTarget.classList.remove('show'); });
#
#     // Add copy buttons to code blocks
#     document.querySelectorAll('.code').forEach(block=>{
#       block.classList.add('wraprel');
#       const btn=document.createElement('button'); btn.className='copy-btn'; btn.textContent='Copy';
#       btn.addEventListener('click', async()=>{ try{ await navigator.clipboard.writeText(block.innerText); btn.textContent='Copied!'; setTimeout(()=>btn.textContent='Copy',1200);}catch{btn.textContent='Error';}});
#       block.appendChild(btn);
#     });
#
#     // TOC active link highlight
#     const tocLinks=[...document.querySelectorAll('.toc a')]; const secIds=tocLinks.map(a=>a.getAttribute('href'));
#     const so=new IntersectionObserver((ents)=>{
#       ents.forEach(en=>{ if(!en.isIntersecting) return; const id='#'+en.target.id; tocLinks.forEach(a=>a.classList.toggle('active', a.getAttribute('href')===id)); });
#     },{rootMargin:'-40% 0px -50% 0px', threshold:0});
#     secIds.forEach(id=>{ const s=document.querySelector(id); if(s) so.observe(s); });
#
#     // Confetti on game win
#     (function(){
#       const status=document.getElementById('status'); if(!status) return; const conf=document.createElement('canvas'); conf.width=innerWidth; conf.height=innerHeight; conf.style.cssText='position:fixed;inset:0;pointer-events:none;z-index:9997;display:none'; document.body.appendChild(conf); const cx=conf.getContext('2d');
#       function burst(){ conf.width=innerWidth; conf.height=innerHeight; conf.style.display='block'; const pieces=Array.from({length:120},()=>({x:innerWidth/2,y:innerHeight/3+40,vx:(Math.random()-0.5)*6,vy:(Math.random()-1.2)*6,sz:2+Math.random()*4,rot:Math.random()*6.28,vr:(Math.random()-.5)*.2,col:`hsl(${Math.random()*360},90%,60%)`}));
#         let t=0; (function anim(){ cx.clearRect(0,0,conf.width,conf.height); pieces.forEach(p=>{ p.x+=p.vx; p.y+=p.vy+=0.05; p.rot+=p.vr; cx.save(); cx.translate(p.x,p.y); cx.rotate(p.rot); cx.fillStyle=p.col; cx.fillRect(-p.sz/2,-p.sz/2,p.sz,p.sz); cx.restore(); }); if((t+=1)<220) requestAnimationFrame(anim); else conf.style.display='none'; })(); }
#       const orig=moveBy; window.moveBy=function(d){ orig(d); if(status.textContent.includes('You win')) burst(); };
#       addEventListener('keydown',e=>{ if(e.key==='ArrowRight'){ document.getElementById('roll').click(); }});
#     })();
#
#   </script>
# </div>

# %% [markdown]
# <!--
# Paste this ENTIRE block into a Markdown (.md) file. Most Markdown engines (incl. GitHub/Jekyll) allow raw HTML/CSS/JS.
# Self‑contained, no external libs. Styled like the lesson UI, but this is an interactive HOMEWORK worksheet.
# Includes: scroll progress, panels, sticky help bar, answer inputs, auto‑save to localStorage, and light validation.
# Replace any image/video src with your own files when you publish.
# -->
#
# <div id="csp-app" class="csp-root">
#   <style>
#     :root{
#       --bg:#0b0c0f; --panel:#12141a; --ink:#f6f7fb; --muted:#c9cbd4; --accent:#7bc6ff; --accent2:#83ffb4; --warn:#ffc773;
#       --shadow:0 18px 40px rgba(0,0,0,.35); --radius:22px; --w:min(1100px,92vw);
#     }
#     @media(prefers-color-scheme:light){:root{--bg:#f7f8fb;--panel:#ffffff;--ink:#0b0c0f;--muted:#394150;--shadow:0 10px 26px rgba(0,0,0,.12)}}
#     *{box-sizing:border-box}
#     body{margin:0}
#     .csp-root{color:var(--ink); background:radial-gradient(1200px 600px at 80% -10%, #1b1f2a 10%, transparent 60%), var(--bg); font:16px ui-sans-serif,system-ui,-apple-system,Segoe UI,Roboto,Arial; line-height:1.55; overflow-x:hidden}
#     .csp-progress{position:fixed; inset:0 0 auto 0; height:4px; background:linear-gradient(90deg,var(--accent),var(--accent2)); transform:scaleX(0); transform-origin:left; z-index:9999}
#     .wrap{width:var(--w); margin:0 auto}
#
#     /* BLOG FULL‑BLEED FIX */
#     :where(.markdown-body,.post-content,.post,.page-content) #csp-app,
#     #csp-app.fullbleed{ --bleed: calc(50vw - 50%); width:auto; max-width:none; margin-left: calc(-1 * var(--bleed)); margin-right: calc(-1 * var(--bleed)); }
#     :where(.markdown-body,.post-content,.post,.page-content){ overflow: visible !important; }
#
#     /* HERO */
#     header.csp-hero{position:relative; min-height:46vh; display:grid; place-items:center; overflow:hidden}
#     .hero-bg{position:absolute; inset:-10% -10% -10% -10%; background:
#       radial-gradient(1200px 700px at 20% -10%, rgba(131,255,180,.25), transparent 60%),
#       radial-gradient(1200px 700px at 80% 110%, rgba(123,198,255,.25), transparent 60%);
#       will-change:transform; filter:saturate(105%) contrast(105%)}
#     header.csp-hero::after{content:""; position:absolute; inset:0; background:linear-gradient(180deg, rgba(0,0,0,.35), transparent 40%, rgba(0,0,0,.55))}
#     .hero-inner{position:relative; text-align:center; padding:12vh 0}
#     .kicker{letter-spacing:.18em; text-transform:uppercase; color:var(--muted)}
#     h1{font-weight:800; font-size:clamp(28px,5.4vw,62px); margin:.35em 0}
#     .sub{color:var(--muted); font-size:clamp(14px,2vw,20px); max-width:70ch; margin:0 auto 12px}
#
#     /* PANELS */
#     section{margin:clamp(36px,8vh,110px) 0}
#     .panel{background:linear-gradient(180deg, rgba(255,255,255,.06), rgba(255,255,255,.02)); border:1px solid rgba(255,255,255,.08); border-radius:var(--radius); padding:clamp(16px,3vw,28px); box-shadow:var(--shadow)}
#
#     /* FORM ELEMENTS */
#     .q{display:grid; gap:10px}
#     .choice{display:flex; align-items:center; gap:10px; padding:10px 12px; border:1px solid rgba(255,255,255,.15); border-radius:12px; background:rgba(255,255,255,.04); cursor:pointer}
#     .choice input{accent-color:var(--accent)}
#     .inline-input{display:inline-grid; grid-template-columns: 120px 1fr; gap:10px; align-items:center}
#     .short{width:110px}
#     textarea, input[type="text"], input[type="number"]{width:100%; padding:10px 12px; color:var(--ink); background:rgba(0,0,0,.35); border:1px solid rgba(255,255,255,.12); border-radius:10px}
#     table{width:100%; border-collapse:separate; border-spacing:0; overflow:hidden; border-radius:14px}
#     th,td{padding:10px 12px; border-bottom:1px solid rgba(255,255,255,.12)}
#     thead th{background:rgba(255,255,255,.08); text-align:left}
#
#     /* STICKY BAR */
#     .bar{position:sticky; top:10px; z-index:5; margin-bottom:14px}
#     .bar .panel{display:flex; gap:10px; align-items:center; justify-content:space-between}
#     .btn{appearance:none; border:1px solid transparent; background:var(--ink); color:var(--bg); padding:10px 14px; border-radius:999px; font-weight:700; cursor:pointer; box-shadow:var(--shadow)}
#     .btn.ghost{background:transparent; color:var(--ink); border-color:rgba(255,255,255,.25)}
#
#     /* REVEAL */
#     .reveal{opacity:1; transform:none}
#     .js .reveal{opacity:0; transform:translateY(18px); transition:opacity .6s ease, transform .6s ease}
#     .js .reveal.in{opacity:1; transform:none}
#
#     footer{padding:48px 0 80px; color:var(--muted); text-align:center}
#   </style>
#
#   <div class="csp-progress" id="csp-progress"></div>
#
#   <!-- HERO -->
#   <header class="csp-hero" role="banner">
#     <div class="hero-bg" id="hero-bg"></div>
#     <div class="hero-inner wrap">
#       <div class="kicker">AP CSP • Homework</div>
#       <h1>📝 CSP Homework — Problems, Algorithms, and Efficiency</h1>
#       <p class="sub">Complete the items below. Your answers auto‑save to this browser. Use the sticky bar to export or reset.</p>
#     </div>
#   </header>
#
#   <!-- Sticky tools -->
#   <div class="wrap bar reveal">
#     <div class="panel">
#       <div style="display:flex; gap:8px; align-items:center; flex-wrap:wrap">
#         <button class="btn" id="export">Export Answers</button>
#         <button class="btn ghost" id="reset">Reset</button>
#       </div>
#       <small style="color:var(--muted)">Progress saves automatically.</small>
#     </div>
#   </div>
#
#   <main>
#     <!-- Problem 1 -->
#     <section class="wrap reveal" id="p1">
#       <div class="panel">
#         <h2>Problem 1 – Decision vs Optimization</h2>
#         <div class="q">
#           <div class="choice"><label style="width:100%">A. Is there a path from your house to school?
#             <div style="display:flex; gap:16px; margin-top:8px">
#               <label><input type="radio" name="p1a" value="Decision"> Decision</label>
#               <label><input type="radio" name="p1a" value="Optimization"> Optimization</label>
#             </div></label></div>
#           <div class="choice"><label style="width:100%">B. What is the shortest path from your house to school?
#             <div style="display:flex; gap:16px; margin-top:8px">
#               <label><input type="radio" name="p1b" value="Decision"> Decision</label>
#               <label><input type="radio" name="p1b" value="Optimization"> Optimization</label>
#             </div></label></div>
#           <div class="choice"><label style="width:100%">C. Can all classes fit into a weekly schedule without overlap?
#             <div style="display:flex; gap:16px; margin-top:8px">
#               <label><input type="radio" name="p1c" value="Decision"> Decision</label>
#               <label><input type="radio" name="p1c" value="Optimization"> Optimization</label>
#             </div></label></div>
#           <div class="choice"><label style="width:100%">D. Minimize total travel time for deliveries to 10 cities.
#             <div style="display:flex; gap:16px; margin-top:8px">
#               <label><input type="radio" name="p1d" value="Decision"> Decision</label>
#               <label><input type="radio" name="p1d" value="Optimization"> Optimization</label>
#             </div></label></div>
#         </div>
#       </div>
#     </section>
#
#     <!-- Problem 2 -->
#     <section class="wrap reveal" id="p2">
#       <div class="panel">
#         <h2>Problem 2 – Algorithm Efficiency Table</h2>
#         <table>
#           <thead><tr><th>Input Size (n)</th><th>Algorithm X Steps</th><th>Algorithm Y Steps</th><th>Algorithm Z Steps</th></tr></thead>
#           <tbody>
#             <tr><td>1</td><td>3</td><td>2</td><td>1</td></tr>
#             <tr><td>2</td><td>6</td><td>4</td><td>2</td></tr>
#             <tr><td>3</td><td>9</td><td>8</td><td>6</td></tr>
#             <tr><td>4</td><td>12</td><td>16</td><td>24</td></tr>
#             <tr><td>5</td><td>15</td><td>32</td><td>120</td></tr>
#           </tbody>
#         </table>
#         <div class="q" style="margin-top:12px">
#           <label>1) Identify the growth type of each: X <input class="short" data-key="p2-x" placeholder="e.g., Linear"/> , Y <input class="short" data-key="p2-y"/> , Z <input class="short" data-key="p2-z"/>.</label>
#           <label>2) Which algorithm is most reasonable for large n? <input class="short" data-key="p2-best"/></label>
#         </div>
#       </div>
#     </section>
#
#     <!-- Problem 3 -->
#     <section class="wrap reveal" id="p3">
#       <div class="panel">
#         <h2>Problem 3 – Fill in the Algorithm Table</h2>
#         <p>Algorithm A grows by <code>3ⁿ</code>. Complete the missing steps.</p>
#         <table>
#           <thead><tr><th>Input Size (n)</th><th>Algorithm A Steps</th></tr></thead>
#           <tbody>
#             <tr><td>1</td><td>3</td></tr>
#             <tr><td>2</td><td><input type="number" class="short" data-key="p3-n2" placeholder="?"/></td></tr>
#             <tr><td>3</td><td><input type="number" class="short" data-key="p3-n3" placeholder="?"/></td></tr>
#             <tr><td>4</td><td><input type="number" class="short" data-key="p3-n4" placeholder="?"/></td></tr>
#             <tr><td>5</td><td><input type="number" class="short" data-key="p3-n5" placeholder="?"/></td></tr>
#           </tbody>
#         </table>
#         <div class="q" style="margin-top:12px">
#           <label>Efficiency type of A: <input class="short" data-key="p3-type" placeholder="e.g., Exponential"/></label>
#           <label>Reasonable for large n? <select data-key="p3-reas"><option value="">—</option><option>Yes</option><option>No</option></select></label>
#         </div>
#         <button class="btn ghost" id="p3-check">Check (optional)</button>
#         <div id="p3-msg" style="margin-top:8px; color:var(--muted)"></div>
#       </div>
#     </section>
#
#     <!-- Problem 4 -->
#     <section class="wrap reveal" id="p4">
#       <div class="panel">
#         <h2>Problem 4 – Counting Steps</h2>
#         <p>Compares every pair of items in a list of size n.</p>
#         <div class="q">
#           <div class="choice"><label>1) How many steps for n = 4?
#             <div style="display:flex; gap:16px; margin-top:8px; flex-wrap:wrap">
#               <label><input type="radio" name="p4-1" value="4"> 4</label>
#               <label><input type="radio" name="p4-1" value="8"> 8</label>
#               <label><input type="radio" name="p4-1" value="16"> 16</label>
#               <label><input type="radio" name="p4-1" value="24"> 24</label>
#             </div></label></div>
#           <div class="choice"><label>2) Efficiency type?
#             <div style="display:flex; gap:16px; margin-top:8px; flex-wrap:wrap">
#               <label><input type="radio" name="p4-2" value="O(n)"> O(n)</label>
#               <label><input type="radio" name="p4-2" value="O(n²)"> O(n²)</label>
#               <label><input type="radio" name="p4-2" value="O(2ⁿ)"> O(2ⁿ)</label>
#               <label><input type="radio" name="p4-2" value="O(n!)"> O(n!)</label>
#             </div></label></div>
#           <div class="choice"><label>3) Reasonable for very large lists?
#             <label style="margin-left:10px"><input type="radio" name="p4-3" value="Yes"> Yes</label>
#             <label style="margin-left:10px"><input type="radio" name="p4-3" value="No"> No</label>
#           </label></div>
#         </div>
#       </div>
#     </section>
#
#     <!-- Problem 5 -->
#     <section class="wrap reveal" id="p5">
#       <div class="panel">
#         <h2>Problem 5 – Heuristic Scenario</h2>
#         <p>A city wants to design bus routes covering all neighborhoods. There are hundreds of possible routes, and finding the perfect shortest set is too complex.</p>
#         <div class="q">
#           <label>Explain one heuristic approach the city could use.<br>
#             <textarea rows="4" data-key="p5-heur" placeholder="e.g., Start at a central hub and repeatedly add the nearest uncovered neighborhood…"></textarea>
#           </label>
#           <label>Why might this heuristic not give the optimal solution?<br>
#             <textarea rows="3" data-key="p5-why"></textarea>
#           </label>
#         </div>
#       </div>
#     </section>
#
#     <!-- Problem 6 -->
#     <section class="wrap reveal" id="p6">
#       <div class="panel">
#         <h2>Problem 6 – Algorithm Steps Table</h2>
#         <table>
#           <thead><tr><th>Input Size (n)</th><th>Algorithm B Steps</th></tr></thead>
#           <tbody>
#             <tr><td>1</td><td>2</td></tr>
#             <tr><td>2</td><td>4</td></tr>
#             <tr><td>3</td><td>8</td></tr>
#             <tr><td>4</td><td><input type="number" class="short" data-key="p6-n4" placeholder="?"/></td></tr>
#             <tr><td>5</td><td><input type="number" class="short" data-key="p6-n5" placeholder="?"/></td></tr>
#           </tbody>
#         </table>
#         <div class="q" style="margin-top:12px">
#           <label>Identify efficiency: <select data-key="p6-type"><option value="">—</option><option>Linear</option><option>Quadratic</option><option>Exponential</option><option>Factorial</option></select></label>
#           <label>Reasonable for large n? <select data-key="p6-reas"><option value="">—</option><option>Yes</option><option>No</option></select></label>
#         </div>
#       </div>
#     </section>
#
#     <!-- Problem 7 -->
#     <section class="wrap reveal" id="p7">
#       <div class="panel">
#         <h2>Problem 7 – TSP Heuristic</h2>
#         <div class="q">
#           <label class="choice"><input type="checkbox" data-key="p7-a"> A. Check <strong>all 120 possible routes</strong></label>
#           <label class="choice"><input type="checkbox" data-key="p7-b"> B. Always go to the <strong>nearest unvisited city</strong> next</label>
#           <label class="choice"><input type="checkbox" data-key="p7-c"> C. Randomly choose cities and hope for the shortest path</label>
#           <label class="choice"><input type="checkbox" data-key="p7-d"> D. List routes alphabetically</label>
#           <small class="muted">Select all that apply.</small>
#         </div>
#       </div>
#     </section>
#
#     <!-- Problem 8 -->
#     <section class="wrap reveal" id="p8">
#       <div class="panel">
#         <h2>Problem 8 – Efficiency Ranking</h2>
#         <table>
#           <thead><tr><th>Input Size (n)</th><th>Algorithm P</th><th>Algorithm Q</th><th>Algorithm R</th></tr></thead>
#           <tbody>
#             <tr><td>1</td><td>1</td><td>3</td><td>2</td></tr>
#             <tr><td>2</td><td>2</td><td>9</td><td>4</td></tr>
#             <tr><td>3</td><td>3</td><td>27</td><td>8</td></tr>
#             <tr><td>4</td><td>4</td><td>81</td><td>16</td></tr>
#             <tr><td>5</td><td>5</td><td>243</td><td>32</td></tr>
#           </tbody>
#         </table>
#         <div class="q" style="margin-top:12px">
#           <label>Rank (most → least efficient):
#             <input data-key="p8-rank" placeholder="e.g., P, R, Q"/>
#           </label>
#           <label>Which are reasonable for large n?
#             <input data-key="p8-reasonable" placeholder="e.g., P and R"/>
#           </label>
#         </div>
#       </div>
#     </section>
#   </main>
#
#   <footer>
#     Built with 💙 for interactive CSP homework. Answers are saved locally in this browser.
#   </footer>
#
#   <script>
#     // Flag: JS is enabled → enable animated reveals only when scripts run
#     document.documentElement.classList.add('js');
#     // Progress bar
#     const prog = document.getElementById('csp-progress');
#     const onScroll = () => { const p = window.scrollY / (document.body.scrollHeight - innerHeight); prog.style.transform = `scaleX(${p})`; }; window.addEventListener('scroll', onScroll);
#
#     // Parallax hero bg
#     const hero = document.getElementById('hero-bg');
#     window.addEventListener('scroll', () => { const y = window.scrollY * 0.12; hero.style.transform = `translateY(${y}px)`; });
#
#     // Reveal on scroll
#     const io = new IntersectionObserver((ents)=>ents.forEach(e=>e.target.classList.toggle('in', e.isIntersecting)),{threshold:.15});
#     document.querySelectorAll('.reveal').forEach(el=>io.observe(el));
#
#     // Auto-save + restore (localStorage)
#     const KEY = 'csp_hw_answers_v1';
#     function collect(){
#       const data = {};
#       // text/number/select
#       document.querySelectorAll('[data-key]').forEach(el=>{ data[el.getAttribute('data-key')] = el.value; });
#       // radios
#       document.querySelectorAll('input[type=radio]:checked').forEach(r=>{ data[r.name] = r.value; });
#       // checkboxes
#       document.querySelectorAll('input[type=checkbox]').forEach(c=>{ data[c.getAttribute('data-key')] = c.checked; });
#       localStorage.setItem(KEY, JSON.stringify(data));
#       return data;
#     }
#     function restore(){
#       try{ const data = JSON.parse(localStorage.getItem(KEY)||'{}');
#         Object.entries(data).forEach(([k,v])=>{
#           const el = document.querySelector(`[data-key="${k}"]`);
#           if(el){ if(el.type==='checkbox'){ el.checked=!!v; } else if(el.tagName==='SELECT' || el.tagName==='INPUT' || el.tagName==='TEXTAREA'){ el.value=v; }}
#           const radio = document.querySelector(`input[type=radio][name="${k}"][value="${v}"]`);
#           if(radio) radio.checked = true;
#         });
#       }catch{}
#     }
#     restore();
#     document.addEventListener('input', collect);
#
#     // Export / Reset
#     document.getElementById('export').addEventListener('click', ()=>{
#       const data = collect();
#       const blob = new Blob([JSON.stringify(data, null, 2)], {type:'application/json'});
#       const url = URL.createObjectURL(blob); const a = document.createElement('a'); a.href=url; a.download='csp-homework-answers.json'; a.click(); setTimeout(()=>URL.revokeObjectURL(url), 500);
#     });
#     document.getElementById('reset').addEventListener('click', ()=>{ if(confirm('Clear all saved answers?')){ localStorage.removeItem(KEY); location.reload(); }});
#
#     // Optional checker for Problem 3 (3^n)
#     document.getElementById('p3-check').addEventListener('click', ()=>{
#       const expected = {2:9,3:27,4:81,5:243}; const msg = document.getElementById('p3-msg');
#       let ok=true; Object.entries(expected).forEach(([n,val])=>{ const el=document.querySelector(`[data-key="p3-n${n}"]`); if(!el) return; const good = Number(el.value)===val; el.style.borderColor = good? 'rgba(131,255,180,.8)' : '#ff5c84'; ok = ok && good; });
#       msg.textContent = ok ? 'Looks good! A is exponential (3ⁿ) and not reasonable for large n.' : 'Some entries don’t match 3ⁿ. Try again.';
#     });
#   </script>
# </div>

# %% [markdown]
# <!--
# Paste this ENTIRE block into a Markdown (.md) file. Most Markdown engines (incl. GitHub/Jekyll) allow raw HTML/CSS/JS.
# Self-contained: no external libs. Includes: parallax hero, scroll progress, sticky scrollytelling, reveal animations,
# inline SVG characters, interactive operator visualizer, MCQs with instant feedback, PEMDAS step demo, and free-response.
# Replace any image/video src with your own files when you publish.
# -->
#
# <div id="csp-app" class="csp-root">
#   <style>
#     :root{
#       --bg:#0b0c0f; --panel:#12141a; --ink:#f6f7fb; --muted:#c9cbd4; --accent:#7bc6ff; --accent2:#83ffb4; --warn:#ffc773;
#       --shadow:0 18px 40px rgba(0,0,0,.35); --radius:22px; --w:min(1100px,92vw);
#     }
#     @media(prefers-color-scheme:light){:root{--bg:#f7f8fb;--panel:#ffffff;--ink:#0b0c0f;--muted:#394150;--shadow:0 10px 26px rgba(0,0,0,.12)}}
#     *{box-sizing:border-box}
#     body{margin:0}
#     .csp-root{color:var(--ink); background:radial-gradient(1200px 600px at 80% -10%, #1b1f2a 10%, transparent 60%), var(--bg); font:16px ui-sans-serif,system-ui,-apple-system,Segoe UI,Roboto,Arial; line-height:1.55; overflow-x:hidden}
#     .csp-progress{position:fixed; inset:0 0 auto 0; height:4px; background:linear-gradient(90deg,var(--accent),var(--accent2)); transform:scaleX(0); transform-origin:left; z-index:9999}
#     .wrap{width:var(--w); margin:0 auto}
#
#     /* BLOG FULL-BLEED FIX */
#     :where(.markdown-body,.post-content,.post,.page-content) #csp-app,
#     #csp-app.fullbleed{
#       --bleed: calc(50vw - 50%);
#       width:auto; max-width:none;
#       margin-left: calc(-1 * var(--bleed));
#       margin-right: calc(-1 * var(--bleed));
#     }
#     :where(.markdown-body,.post-content,.post,.page-content){ overflow: visible !important; }
#
#     /* HERO */
#     header.csp-hero{position:relative; min-height:92vh; display:grid; place-items:center; overflow:hidden}
#     .hero-bg{position:absolute; inset:-10% -10% -10% -10%; background:
#       radial-gradient(1200px 700px at 20% -10%, rgba(131,255,180,.25), transparent 60%),
#       radial-gradient(1200px 700px at 80% 110%, rgba(123,198,255,.25), transparent 60%),
#       url('data:image/svg+xml;utf8,<svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 1200 800"><defs><linearGradient id="g" x1="0" x2="1"><stop offset="0" stop-color="%230b0c0f"/><stop offset="1" stop-color="%23161a22"/></linearGradient></defs><rect width="1200" height="800" fill="url(%23g)"/><g fill="none" stroke="%2346a4ff" stroke-opacity="0.18"><circle cx="300" cy="400" r="240"/><circle cx="900" cy="460" r="260"/></g></svg>') center/cover no-repeat; will-change:transform; filter:saturate(105%) contrast(105%)}
#     header.csp-hero::after{content:""; position:absolute; inset:0; background:linear-gradient(180deg, rgba(0,0,0,.35), transparent 40%, rgba(0,0,0,.55))}
#     .hero-inner{position:relative; text-align:center; padding:22vh 0}
#     .kicker{letter-spacing:.18em; text-transform:uppercase; color:var(--muted)}
#     h1{font-weight:800; font-size:clamp(32px,6vw,72px); margin:.35em 0}
#     .sub{color:var(--muted); font-size:clamp(16px,2.2vw,22px); max-width:60ch; margin:0 auto 24px}
#     .cta-row{display:flex; gap:12px; justify-content:center; flex-wrap:wrap; margin-top:20px}
#     .btn{appearance:none; border:1px solid transparent; background:var(--ink); color:var(--bg); padding:12px 18px; border-radius:999px; font-weight:700; cursor:pointer; box-shadow:var(--shadow); transition:.25s transform}
#     .btn:hover{transform:translateY(-2px)}
#     .btn.ghost{background:transparent; color:var(--ink); border-color:rgba(255,255,255,.25)}
#
#     /* REVEAL */
#     .reveal{opacity:0; transform:translateY(18px); transition:opacity .6s ease, transform .6s ease}
#     .reveal.in{opacity:1; transform:none}
#
#     /* PANELS */
#     section{margin:clamp(48px,10vh,140px) 0}
#     .panel{background:linear-gradient(180deg, rgba(255,255,255,.06), rgba(255,255,255,.02)); border:1px solid rgba(255,255,255,.08); border-radius:var(--radius); padding:clamp(16px,3vw,28px); box-shadow:var(--shadow)}
#
#     /* GRID */
#     .scrolly{display:grid; grid-template-columns: 1.06fr .94fr; gap:clamp(16px,3vw,28px)}
#     .steps{position:relative}
#     .step{padding:16px 18px; border-radius:16px; margin:12px 0; border:1px solid rgba(255,255,255,.08); background:linear-gradient(180deg, rgba(255,255,255,.06), rgba(255,255,255,0))}
#     .step.is-active{outline:2px solid var(--accent); background:linear-gradient(180deg, rgba(123,198,255,.18), rgba(123,198,255,.05))}
#     .stage{position:sticky; top:12vh}
#     .device{position:relative; overflow:hidden; border-radius:26px; border:1px solid rgba(255,255,255,.1); box-shadow:var(--shadow)}
#     .device::after{content:""; position:absolute; inset:0; box-shadow: inset 0 0 0 2px rgba(255,255,255,.04); pointer-events:none; border-radius:26px}
#     .device img, .device video{display:block; width:100%; height:auto}
#     .device .caption{position:absolute; left:0; right:0; bottom:0; padding:12px 16px; color:#fff; background:linear-gradient(180deg, transparent, rgba(0,0,0,.55)); font-size:14px}
#
#     /* STATS */
#     .stats{display:grid; grid-template-columns: repeat(4, 1fr); gap: clamp(12px, 2vw, 20px)}
#     .stat{padding:18px; border-radius:16px; background:linear-gradient(180deg, rgba(255,255,255,.06), rgba(255,255,255,.01)); border:1px solid rgba(255,255,255,.08); text-align:center}
#     .stat .num{font-weight:900; font-size: clamp(22px, 3.6vw, 42px)}
#     .stat .label{color:var(--muted)}
#
#     /* TABLE — higher contrast & clarity */
#     .table-elevated{width:100%; border-collapse:separate; border-spacing:0; overflow:hidden; border-radius:16px; background:rgba(255,255,255,.03); box-shadow:var(--shadow)}
#     .table-elevated thead th{position:sticky; top:0; z-index:2; background:linear-gradient(180deg, rgba(255,255,255,.14), rgba(255,255,255,.08)); text-align:left; font-weight:800; letter-spacing:.2px; border-bottom:1px solid rgba(255,255,255,.22)}
#     .table-elevated th, .table-elevated td{padding:16px 18px; border-bottom:1px solid rgba(255,255,255,.12); font-size:clamp(15px,1.5vw,17px)}
#     .table-elevated tbody tr:nth-child(odd){background:rgba(255,255,255,.03)}
#     .table-elevated tbody tr:hover{background:rgba(123,198,255,.12)}
#     .table-elevated code{font-weight:700}
#
#     /* CHARS */
#     .chars{display:flex; gap:14px; align-items:center}
#     .chip{display:inline-flex; align-items:center; gap:8px; padding:8px 12px; border-radius:999px; border:1px solid rgba(255,255,255,.15); background:rgba(255,255,255,.05)}
#     .blink{animation: blink 2s infinite}
#     @keyframes blink{0%,90%,100%{opacity:1}95%{opacity:.1}}
#
#     /* VIZ */
#     .viz{display:grid; gap:14px}
#     .bar{height:16px; border-radius:999px; background:linear-gradient(90deg,var(--accent),var(--accent2)); width:10%}
#     .bar.warn{background:linear-gradient(90deg,#ff9d73, #ff5c84)}
#     .viz-controls{display:flex; gap:10px; align-items:center; flex-wrap:wrap}
#     .code{font: 14px ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace; background:rgba(0,0,0,.35); border:1px solid rgba(255,255,255,.12); border-radius:12px; padding:8px 10px; overflow:auto}
#
#     /* QUIZ */
#     .quiz{display:grid; gap:10px}
#     .opt{padding:12px; border:1px solid rgba(255,255,255,.18); border-radius:12px; cursor:pointer; background:rgba(255,255,255,.04)}
#     .opt[aria-checked="true"]{outline:2px solid var(--accent)}
#     .opt.correct{outline:2px solid var(--accent2)}
#     .opt.wrong{outline:2px solid #ff5c84}
#     .toast{margin-top:10px; color:var(--muted)}
#
#     footer{padding:48px 0 80px; color:var(--muted); text-align:center}
#
#     @media(max-width:920px){.scrolly{grid-template-columns:1fr}.stats{grid-template-columns:repeat(2,1fr)}}
#
#     /* Motion + goodies */
#     @keyframes popIn{0%{opacity:0; transform:translateY(24px) scale(.95)}70%{opacity:1}100%{transform:none}}
#     .reveal.in{animation: popIn .7s cubic-bezier(.2,.7,.2,1) both}
#     .pop:hover{transform: translateY(-3px) scale(1.02)}
#     .btn.magnetic{transition: transform .15s ease-out}
#     html:focus-within{scroll-behavior:smooth}
#     #particles{position:fixed; inset:0; pointer-events:none; z-index:0; opacity:.4}
#     header.csp-hero, main, footer{position:relative; z-index:1}
#     .toc{position:sticky; top:12px; background:linear-gradient(180deg, rgba(255,255,255,.06), rgba(255,255,255,.02)); border:1px solid rgba(255,255,255,.08); border-radius:14px; padding:10px 12px; box-shadow:var(--shadow); display:flex; gap:10px; flex-wrap:wrap}
#     .toc a{color:var(--muted); text-decoration:none; padding:6px 10px; border-radius:999px; border:1px solid rgba(255,255,255,.12)}
#     .toc a.active{color:var(--ink); border-color:var(--accent)}
#     #lightbox{position:fixed; inset:0; background:rgba(0,0,0,.7); display:none; align-items:center; justify-content:center; z-index:9998}
#     #lightbox.show{display:flex}
#     #lightbox .frame{max-width:min(94vw,1100px); max-height:90vh; border-radius:14px; overflow:hidden; box-shadow:var(--shadow); background:#000}
#     #lightbox .frame img, #lightbox .frame video{width:100%; height:auto; display:block}
#     .copy-btn{position:absolute; right:10px; top:10px; font:13px ui-monospace,monospace; padding:6px 10px; border-radius:10px; border:1px solid rgba(255,255,255,.35); background:linear-gradient(180deg, rgba(255,255,255,.22), rgba(255,255,255,.06)); color:var(--ink); box-shadow:var(--shadow); opacity:.98}
#     .copy-btn:hover{transform:translateY(-1px);}
#     .code.wraprel{position:relative}
#
#     /* Dolphin pod */
#     #dolphin-pod{position:fixed; right:18px; top:18vh; width:140px; height:64vh; pointer-events:none; z-index:2; display:flex; align-items:flex-start; justify-content:center; gap:8px; opacity:0; transform:translateX(40px)}
#     #dolphin-pod.show{opacity:1; transform:none; transition:opacity .8s ease, transform .8s cubic-bezier(.2,.7,.2,1)}
#     .dolphin{width:120px; filter:drop-shadow(0 6px 18px rgba(0,0,0,.35))}
#     .dolphin svg{display:block; width:100%; height:auto}
#     .swim{animation: swimY var(--dur,9s) linear infinite, swimX 6s ease-in-out infinite alternate}
#     @keyframes swimY{0%{transform:translateY(-5%)}100%{transform:translateY(105%)}}
#     @keyframes swimX{0%{transform:translateX(0)}100%{transform:translateX(-12px)}}
#
#     @media (prefers-reduced-motion: reduce){
#       *{animation:none!important; transition:none!important}
#       #dolphin-pod{display:none}
#     }
#   </style>
#
#   <div class="csp-progress" id="csp-progress"></div>
#
#   <!-- HERO -->
#   <header class="csp-hero" role="banner">
#     <div class="hero-bg" id="hero-bg"></div>
#     <div class="hero-inner wrap">
#       <div class="kicker">AP CSP • Unit 3.3</div>
#       <h1>🧮 Mathematical Expressions</h1>
#       <p class="sub">A scroll-driven, Apple-style walkthrough of expressions, operators, MOD, distance formula, PEMDAS, and graded practice — all in one file.</p>
#       <div class="cta-row">
#         <a href="#s-overview" class="btn">Start Lesson</a>
#         <a href="#s-operators" class="btn ghost">Jump to Operators</a>
#       </div>
#       <div class="chars" style="justify-content:center; margin-top:16px">
#         <span class="chip"><svg width="20" height="20" viewBox="0 0 24 24" fill="none"><circle cx="12" cy="12" r="10" fill="#7bc6ff"/><circle class="blink" cx="9" cy="10" r="1.5" fill="#0b0c0f"/><circle cx="15" cy="10" r="1.5" fill="#0b0c0f"/><rect x="8" y="14" width="8" height="2" rx="1" fill="#0b0c0f"/></svg> Expr-Bot</span>
#         <span class="chip"><svg width="20" height="20" viewBox="0 0 24 24" fill="none"><rect x="2" y="4" width="20" height="16" rx="4" fill="#83ffb4"/><circle cx="9" cy="12" r="2" fill="#0b0c0f"/><circle cx="15" cy="12" r="2" fill="#0b0c0f"/></svg> PEMDAS-Pal</span>
#       </div>
#     </div>
#   </header>
#
#   <nav class="wrap toc reveal" aria-label="Lesson sections">
#     <a href="#s-overview">Overview</a>
#     <a href="#s-operators">Operators</a>
#     <a href="#s-distance">Distance Example</a>
#     <a href="#s-order">Order of Operations</a>
#     <a href="#s-mcq">Homework MCQ</a>
#     <a href="#s-frq">Free Response</a>
#     <a href="#s-resources">Resources</a>
#   </nav>
#
#   <main>
#     <!-- OVERVIEW -->
#     <section class="wrap scrolly" id="s-overview">
#       <div class="steps">
#         <div class="step" data-caption="Expressions combine values, variables, operators, and functions.">
#           <h2>📘 What Are Mathematical Expressions?</h2>
#           <p>In programming, a <strong>mathematical expression</strong> is a combination of values, variables, operators, and functions that the computer <em>evaluates</em> to produce a single result.</p>
#           <div class="code" aria-label="Examples">
# - 5 + 3
# - x * y - z
# - abs(a - b)
#           </div>
#         </div>
#         <div class="step" data-caption="Expressions are the engine for calculations and decisions.">
#           <h2>Why They Matter</h2>
#           <p>Expressions drive calculations and affect control flow (e.g., <code>if</code> conditions rely on evaluated results). Mastery here is core to writing correct algorithms.</p>
#         </div>
#         <div class="step" data-caption="One expression → one value.">
#           <h2>Key Takeaways</h2>
#           <ul>
#             <li>Every expression evaluates to <strong>one value</strong>.</li>
#             <li>Operators act on values/variables; functions handle complex work.</li>
#             <li>Operator <strong>precedence</strong> (PEMDAS-like) controls evaluation order.</li>
#           </ul>
#         </div>
#       </div>
#       <div class="stage">
#         <div class="device">
#           <img alt="Expressions concept art" data-lightbox src="data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 800 500'><rect width='800' height='500' fill='%23161a22'/><g fill='none' stroke='%2383ffb4' stroke-width='2'><rect x='120' y='120' width='560' height='260' rx='18' stroke-opacity='.6'/><circle cx='220' cy='250' r='46'/><circle cx='400' cy='250' r='46'/><circle cx='580' cy='250' r='46'/></g><g fill='%237bc6ff' font-size='20' font-family='ui-sans-serif'><text x='199' y='256'>x</text><text x='382' y='256'>op</text><text x='565' y='256'>y</text></g></svg>"/>
#           <div class="caption" id="stage-cap">Expressions combine values, variables, operators, and functions.</div>
#         </div>
#       </div>
#     </section>
#
#     <!-- OPERATORS -->
#     <section class="wrap reveal" id="s-operators">
#       <div class="panel">
#         <h2>🔢 Common Arithmetic Operators</h2>
#         <p class="muted">Note: In <strong>Python</strong>, MOD is represented by <code>%</code>. Exponent is <strong><code>**</code></strong> (not <code>^</code>).</p>
#         <table class="table-elevated">
#           <thead><tr><th>Operator</th><th>Description</th><th>Example</th><th>Evaluates To</th></tr></thead>
#           <tbody>
#             <tr><td><code>+</code></td><td>Addition</td><td><code>5 + 3</code></td><td>8</td></tr>
#             <tr><td><code>-</code></td><td>Subtraction</td><td><code>10 - 6</code></td><td>4</td></tr>
#             <tr><td><code>*</code></td><td>Multiplication</td><td><code>4 * 7</code></td><td>28</td></tr>
#             <tr><td><code>/</code></td><td>Division (float)</td><td><code>7 / 2</code></td><td>3.5</td></tr>
#             <tr><td><code>//</code></td><td>Floor Division</td><td><code>7 // 2</code></td><td>3</td></tr>
#             <tr><td><code>%</code></td><td>Modulo (remainder)</td><td><code>10 % 3</code></td><td>1</td></tr>
#             <tr><td><code>**</code></td><td>Exponent</td><td><code>3 ** 2</code></td><td>9</td></tr>
#           </tbody>
#         </table>
#
#         <details style="margin-top:12px"><summary>💡 Quick MOD intuition</summary>
#           <div class="viz">
#             <div class="viz-controls">
#               <label for="modA">a:</label><input id="modA" type="number" value="10" min="0" style="width:100px">
#               <label for="modB">b:</label><input id="modB" type="number" value="3" min="1" style="width:100px">
#               <button class="btn" id="modCalc">Compute a % b</button>
#               <span id="modOut" class="chip">Result: 1</span>
#             </div>
#             <div class="code" id="modExplain" aria-label="mod explanation">10 divided by 3 → quotient 3, remainder <strong>1</strong>.</div>
#           </div>
#         </details>
#       </div>
#     </section>
#
#     <!-- DISTANCE EXAMPLE -->
#     <section class="wrap reveal" id="s-distance">
#       <div class="panel">
#         <h2>🧪 Example: Calculating Distance</h2>
#         <p>Distance between points <code>(x1, y1)</code> and <code>(x2, y2)</code>:</p>
#         <div class="code">distance = sqrt((x2 - x1)² + (y2 - y1)²)</div>
#         <p>In pseudocode:</p>
#         <div class="code">
# - diffX = x2 - x1
# - diffY = y2 - y1
# - distance = sqrt(diffX * diffX + diffY * diffY)
#         </div>
#         <details style="margin-top:10px"><summary>▶ Try it (live)</summary>
#           <div class="viz-controls" style="margin-top:10px">
#             <label>x1:</label><input id="x1" type="number" value="0" style="width:90px">
#             <label>y1:</label><input id="y1" type="number" value="0" style="width:90px">
#             <label>x2:</label><input id="x2" type="number" value="3" style="width:90px">
#             <label>y2:</label><input id="y2" type="number" value="4" style="width:90px">
#             <button class="btn" id="dCalc">Compute</button>
#             <span id="dOut" class="chip">distance: 5</span>
#           </div>
#         </details>
#       </div>
#     </section>
#
#     <!-- ORDER OF OPERATIONS -->
#     <section class="wrap reveal" id="s-order">
#       <div class="panel">
#         <h2>🧠 Order of Operations (PEMDAS)</h2>
#         <p>Evaluate step-by-step: <code>result = 6 + 4 * 2 % 5</code></p>
#         <div class="cta-row" style="justify-content:flex-start">
#           <button class="btn" id="pemdasStep">Show Steps</button>
#           <span id="pemdasOut" class="chip">result: ?</span>
#         </div>
#         <div class="code" id="pemdasSteps" aria-label="PEMDAS steps"></div>
#         <div class="code" style="margin-top:10px"><strong>Reminder:</strong> In Python, exponent is <code>**</code> not <code>^</code>; <code>^</code> is bitwise XOR.</div>
#       </div>
#     </section>
#
#     <!-- HOMEWORK MCQ -->
#     <section class="wrap reveal" id="s-mcq">
#       <div class="panel">
#         <h2>📚 Homework: Multiple Choice</h2>
#
#         <div class="quiz" role="radiogroup" aria-labelledby="q1lab">
#           <div id="q1lab" class="muted">1) What does this print?</div>
#           <div class="code">x = 10<br/>y = 3<br/>print(x % y + x // y)</div>
#           <div class="opt" data-group="q1" data-correct="true">A. 4</div>
#           <div class="opt" data-group="q1" data-correct="false">B. 5</div>
#           <div class="opt" data-group="q1" data-correct="false">C. 6</div>
#           <div class="opt" data-group="q1" data-correct="false">D. 7</div>
#         </div>
#
#         <hr style="border:none; border-top:1px solid rgba(255,255,255,.15); margin:14px 0"/>
#
#         <div class="quiz" role="radiogroup" aria-labelledby="q2lab">
#           <div id="q2lab" class="muted">2) Best description of a mathematical expression in programming?</div>
#           <div class="opt" data-group="q2" data-correct="false">A. A sequence of steps used to solve a problem</div>
#           <div class="opt" data-group="q2" data-correct="true">B. A combination of values, variables, and operators that evaluates to a single value</div>
#           <div class="opt" data-group="q2" data-correct="false">C. A diagram that represents decision-making in code</div>
#           <div class="opt" data-group="q2" data-correct="false">D. A way to store multiple values in a list</div>
#         </div>
#
#         <hr style="border:none; border-top:1px solid rgba(255,255,255,.15); margin:14px 0"/>
#
#         <div class="quiz" role="radiogroup" aria-labelledby="q3lab">
#           <div id="q3lab" class="muted">3) Given:</div>
#           <div class="code">num1 = 8<br/>num2 = 3<br/>result = num1 * num2 - num1 / num2</div>
#           <div class="opt" data-group="q3" data-correct="true">A. 21.33</div>
#           <div class="opt" data-group="q3" data-correct="false">B. 22.0</div>
#           <div class="opt" data-group="q3" data-correct="false">C. 20.5</div>
#           <div class="opt" data-group="q3" data-correct="false">D. 21.0</div>
#         </div>
#
#         <div class="toast" id="quiz-toast">Choose options — instant feedback will appear.</div>
#       </div>
#     </section>
#
#     <!-- FREE RESPONSE -->
#     <section class="wrap reveal" id="s-frq">
#       <div class="panel">
#         <h2>✍️ Free Response Practice</h2>
#
#         <details open><summary><strong>1) Write a function</strong> that returns <code>(x^2 + y^2) / (x + y)</code>.</summary>
#           <div class="code">
# # Python: remember exponent is ** (not ^)
# def expr(x, y):
#     return (x**2 + y**2) / (x + y)
#           </div>
#           <div class="muted">If you literally use <code>^</code> in Python, you’ll get bitwise XOR, not exponent.</div>
#         </details>
#
#         <details style="margin-top:10px"><summary><strong>2) Explain PEMDAS</strong> for <code>result = 6 + 4 * 2 % 5</code> and show steps.</summary>
#           <div class="code">
# # * and % before +
# # 4 * 2 = 8
# # 8 % 5 = 3  (remainder of 8/5)
# # 6 + 3 = 9
# # result = 9
#           </div>
#         </details>
#       </div>
#     </section>
#
#     <!-- RESOURCES -->
#     <section class="wrap reveal" id="s-resources">
#       <div class="panel">
#         <h2>🔗 Additional Resources</h2>
#         <ul>
#           <li><a href="https://fiveable.me/ap-comp-sci-p/unit-3/mathematical-expressions/study-guide/00lGBdF7QyY5hmd1rubD" target="_blank" rel="noopener">Mathematical Expressions Study Guide (Fiveable)</a></li>
#           <li><a href="https://apcentral.collegeboard.org/media/pdf/ap-computer-science-principles-course-and-exam-description.pdf" target="_blank" rel="noopener">AP CSP Course & Exam Description (AP Central)</a></li>
#         </ul>
#       </div>
#     </section>
#   </main>
#
#   <footer>
#     Built with 💙 for interactive CSP learning. Replace images/videos as needed; everything runs in a single Markdown file.
#   </footer>
#
#   <!-- global particles + lightbox + dolphins -->
#   <canvas id="particles"></canvas>
#   <div id="lightbox" role="dialog" aria-modal="true"><div class="frame" id="lightbox-frame"></div></div>
#   <div id="dolphin-pod" aria-hidden="true"></div>
#
#   <script>
#     // Progress bar
#     const prog = document.getElementById('csp-progress');
#     const onScroll = () => { const p = window.scrollY / (document.body.scrollHeight - innerHeight); prog.style.transform = `scaleX(${p})`; };
#     window.addEventListener('scroll', onScroll);
#
#     // Parallax hero background
#     const hero = document.getElementById('hero-bg');
#     window.addEventListener('scroll', () => { const y = window.scrollY * 0.15; hero.style.transform = `translateY(${y}px)`; });
#
#     // Reveal on scroll
#     const io = new IntersectionObserver((ents)=>ents.forEach(e=>e.target.classList.toggle('in', e.isIntersecting)),{threshold:.15});
#     document.querySelectorAll('.reveal').forEach(el=>io.observe(el));
#
#     // Scrolly captions (optional here; used in overview only)
#     function setupScrolly(rootId, capId){
#       const root = document.querySelector(rootId); if(!root) return;
#       const steps = root.querySelectorAll('.step'); const cap = document.querySelector(capId);
#       const obs = new IntersectionObserver((ents)=>{
#         ents.forEach(en=>{ if(en.isIntersecting){ steps.forEach(s=>s.classList.remove('is-active')); en.target.classList.add('is-active'); if(cap) cap.textContent = en.target.dataset.caption; }});
#       },{rootMargin:'-40% 0px -55% 0px', threshold:0}); steps.forEach(s=>obs.observe(s));
#     }
#     setupScrolly('#s-overview', '#stage-cap');
#
#     // Magnetic buttons effect
#     document.querySelectorAll('.btn.magnetic, .btn').forEach(btn=>{
#       const bounds = ()=>btn.getBoundingClientRect();
#       btn.addEventListener('mousemove', e=>{ const b=bounds(); const x=(e.clientX-b.left-b.width/2)/8; const y=(e.clientY-b.top-b.height/2)/8; btn.style.transform=`translate(${x}px, ${y}px)`; });
#       btn.addEventListener('mouseleave', ()=> btn.style.transform='');
#     });
#
#     // Typewriter for hero subline
#     (function(){ const el=document.querySelector('.sub'); if(!el) return; const text=el.textContent.trim(); el.textContent=''; let i=0; const t=()=>{ if(i<=text.length){ el.textContent=text.slice(0,i++); setTimeout(t, 14); } }; t(); })();
#
#     // Particles
#     (function(){ const c=document.getElementById('particles'); if(!c) return; const ctx=c.getContext('2d'); let W,H; const R=()=>{W=c.width=innerWidth; H=c.height=innerHeight}; R(); addEventListener('resize',R);
#       const dots=Array.from({length:70},()=>({x:Math.random()*W,y:Math.random()*H,vx:(Math.random()-.5)*0.4,vy:(Math.random()-.5)*0.4,r:1+Math.random()*2}));
#       function step(){ ctx.clearRect(0,0,W,H); ctx.globalAlpha=.6; dots.forEach(d=>{ d.x+=d.vx; d.y+=d.vy; if(d.x<0||d.x>W) d.vx*=-1; if(d.y<0||d.y>H) d.vy*=-1; ctx.beginPath(); ctx.arc(d.x,d.y,d.r,0,Math.PI*2); ctx.fillStyle='rgba(123,198,255,.35)'; ctx.fill(); }); requestAnimationFrame(step);} step(); })();
#
#     // Lightbox for images/videos
#     document.querySelectorAll('[data-lightbox] img, [data-lightbox] video, .device img, .device video').forEach(el=>{
#       el.style.cursor='zoom-in';
#       el.addEventListener('click',()=>{
#         const lb=document.getElementById('lightbox'); const frame=document.getElementById('lightbox-frame');
#         frame.innerHTML=''; const clone=el.cloneNode(true); clone.removeAttribute('id'); clone.removeAttribute('style'); if(clone.tagName==='VIDEO'){ clone.controls=true; clone.muted=false; }
#         frame.appendChild(clone); lb.classList.add('show');
#       });
#     });
#     document.getElementById('lightbox').addEventListener('click',e=>{ if(e.target.id==='lightbox') e.currentTarget.classList.remove('show'); });
#
#     // Copy buttons for .code blocks
#     document.querySelectorAll('.code').forEach(block=>{
#       block.classList.add('wraprel');
#       const btn=document.createElement('button'); btn.className='copy-btn'; btn.textContent='Copy';
#       btn.addEventListener('click', async()=>{ try{ await navigator.clipboard.writeText(block.innerText); btn.textContent='Copied!'; setTimeout(()=>btn.textContent='Copy',1200);}catch{btn.textContent='Error';}});
#       block.appendChild(btn);
#     });
#
#     // TOC active link highlight
#     const tocLinks=[...document.querySelectorAll('.toc a')];
#     const secIds=tocLinks.map(a=>a.getAttribute('href'));
#     const so=new IntersectionObserver((ents)=>{
#       ents.forEach(en=>{ if(!en.isIntersecting) return; const id='#'+en.target.id; tocLinks.forEach(a=>a.classList.toggle('active', a.getAttribute('href')===id)); });
#     },{rootMargin:'-40% 0px -50% 0px', threshold:0});
#     secIds.forEach(id=>{ const s=document.querySelector(id); if(s) so.observe(s); });
#
#     // Dolphin pod
#     (function(){
#       const pod = document.getElementById('dolphin-pod'); if(!pod) return;
#       function icon(fill){return `<?xml version='1.0'?><svg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 180 80'>
#         <defs><linearGradient id='g' x1='0' x2='1'><stop offset='0' stop-color='${fill}'/><stop offset='1' stop-color='${fill}AA'/></linearGradient></defs>
#         <g fill='url(%23g)'><path d='M10 45c20-25 55-35 95-26 20 5 36 17 55 34-18-2-31 2-41 8-8 5-14 6-23 5-9-1-18-4-27-10-8 5-19 5-31 1-7-2-16-7-28-12z'/>
#         <circle cx='62' cy='34' r='3' fill='#0b0c0f'/></g></svg>`}
#       const colors=['#9fe3ff','#83ffb4','#b6b3ff'];
#       for(let i=0;i<3;i++){
#         const d=document.createElement('div'); d.className='dolphin swim'; d.style.setProperty('--dur', `${8+i*1.8}s`);
#         d.innerHTML=icon(colors[i%colors.length]); d.style.animationDelay=`-${i*2.3}s`; pod.appendChild(d);
#       }
#       requestAnimationFrame(()=> pod.classList.add('show'));
#     })();
#
#     /* === Interactive widgets === */
#
#     // MOD demo
#     function modExplain(a,b){
#       const q = Math.floor(a/b), r = a - b*q;
#       return `${a} divided by ${b} → quotient ${q}, remainder ${r}.`;
#     }
#     const modCalc = document.getElementById('modCalc');
#     if(modCalc){
#       modCalc.addEventListener('click', ()=>{
#         const a=+document.getElementById('modA').value||0, b=+document.getElementById('modB').value||1;
#         const r = a % b; document.getElementById('modOut').textContent = `Result: ${r}`;
#         document.getElementById('modExplain').innerHTML = modExplain(a,b);
#       });
#     }
#
#     // Distance calculator
#     const dCalc = document.getElementById('dCalc');
#     if(dCalc){
#       dCalc.addEventListener('click', ()=>{
#         const x1=+document.getElementById('x1').value||0;
#         const y1=+document.getElementById('y1').value||0;
#         const x2=+document.getElementById('x2').value||0;
#         const y2=+document.getElementById('y2').value||0;
#         const dx=x2-x1, dy=y2-y1, dist=Math.hypot(dx,dy);
#         document.getElementById('dOut').textContent = `distance: ${+dist.toFixed(5)}`;
#       });
#     }
#
#     // PEMDAS steps for 6 + 4 * 2 % 5
#     const pemdasStep = document.getElementById('pemdasStep');
#     if(pemdasStep){
#       pemdasStep.addEventListener('click', ()=>{
#         const steps = [
#           "Expression: 6 + 4 * 2 % 5",
#           "• Multiply first → 4 * 2 = 8",
#           "• Then modulo → 8 % 5 = 3",
#           "• Finally addition → 6 + 3 = 9",
#           "result = 9"
#         ];
#         document.getElementById('pemdasSteps').innerHTML = steps.join("<br/>");
#         document.getElementById('pemdasOut').textContent = "result: 9";
#       });
#     }
#
#     // MCQ grading
#     document.querySelectorAll('.opt').forEach(opt=>{
#       opt.addEventListener('click', ()=>{
#         const group = opt.dataset.group;
#         const siblings = document.querySelectorAll(`.opt[data-group="${group}"]`);
#         siblings.forEach(o=>{o.setAttribute('aria-checked','false'); o.classList.remove('correct','wrong');});
#         opt.setAttribute('aria-checked','true');
#         if(opt.dataset.correct==='true'){ opt.classList.add('correct'); }
#         else { opt.classList.add('wrong'); }
#         const toast = document.getElementById('quiz-toast');
#         if(group==='q1') toast.textContent = "Q1: 10%3 = 1, 10//3 = 3 → 1+3 = 4 ✅";
#         if(group==='q2') toast.textContent = "Q2: Correct — expressions evaluate to a single value ✅";
#         if(group==='q3') toast.textContent = "Q3: 8*3=24; 8/3≈2.6667 → 24−2.6667≈21.33 ✅";
#       });
#     });
#   </script>
# </div>

# %% [markdown]
# # 3.5: Boolean Expressions and Logic in AP CSP
#
# ## 1. Boolean Values
# - Boolean values represent **true or false** conditions.
# - They are often used to represent conditions in programs.
# - Example:
#
# ```python
# myHairIsBlack = True
# iHaveADog = False
# ```
#
# ## 2. Relational Operators
# - Relational operators compare values and produce a Boolean result (True or False).
# - Here's a helpful table that expresses this:
# | Operator | Meaning                  | Example  | Result  |
# | -------- | ------------------------ | -------- | ------- |
# | `==`     | Equal to                 | `5 == 5` | `True`  |
# | `!=`     | Not equal to             | `4 != 5` | `True`  |
# | `>`      | Greater than             | `7 > 3`  | `True`  |
# | `<`      | Less than                | `2 < 8`  | `True`  |
# | `>=`     | Greater than or equal to | `6 >= 6` | `True`  |
# | `<=`     | Less than or equal to    | `9 <= 4` | `False` |
#
#
# ## 3. The Modulus Operator (%)
# - The modulus operator % gives the remainder when dividing two numbers.
#
# ```python
# print(10 % 2)   # 0, because 10 is evenly divisible by 2
# print(7 % 2)    # 1, because 7 divided by 2 leaves remainder 1
#
# If num % 2 == 0, the number is even.
# If num % 2 != 0, the number is odd.
# ```
#
# ### Try it yourself! Run this in VScode and see if the boolean expression evaluates true or false!
#
# ```python
# # Interactive Practice Quiz: Check if a number is odd
#
# # Ask the student for input
# num1 = int(input("Enter a number: "))
#
# # Boolean expression to check if the number is odd
# is_odd = num1 % 2 != 0
#
# # Show the result
# print(f"Is the number {num1} odd? {is_odd}")
# ```
#
# ## 4. Logical Operators: NOT, AND, OR
# ### NOT (not)
# - What it means: reverses the Boolean value.
# - Example:
# ```python
# isCloudy = True
# print(not isCloudy)   # False
# ```
# ### AND (and)
# - What it means: both conditions must be true.
# - Example:
# ```python
# didHomework = True
# scored80 = True
# canGoOut = didHomework and scored80
# print(canGoOut)   # True
# ```
# ### OR (or)
# - What it means At least one condition must be true.
# ```python
# isWeekend = True
# hasHoliday = False
# dayOff = isWeekend or hasHoliday
# print(dayOff)   # True
# ```
#
# ## Homework problems
# 1. Create two Boolean variables:
# ```python
# isHungry = True
# hasSnack = False
# ```
# What would print(isHungry) display?
# What would print(hasSnack) display?
#
# 2. Predict the output:
# ```python
# print(10 > 5)
# print(7 == 3)
# print(8 <= 8)
# ```
# Write a Boolean expression that checks if grade is at least 90.
#
# 3. Write a Boolean expression that checks if num is even.
# ```python
# Predict the output:
# num = 14
# print(num % 3 == 0)
# ```
#
# 4. Suppose:
# ```python
# studied = True
# didHomework = False
# ```
# Write a Boolean expression using AND to check if the student is fully prepared. What result do you get?
#
# 5. Suppose:
# ```python
# isWeekend = False
# hasHoliday = True
# ```
# Write a Boolean expression using OR to check if there’s a day off. What result do you get?
#
# 6. Suppose:
# ```python
# studied = True
# didHomework = False
# ```
# Write a Boolean expression using AND to check if the student is fully prepared. What result do you get?
#
# 7. Suppose:
# ```python
# isWeekend = False
# hasHoliday = True
# ```
# Write a Boolean expression using OR to check if there’s a day off. What result do you get?
#
# 8. Challenge problem:
# A movie theater gives a discount if:
# - You are under 12 (age < 12)
# - OR you are at least 65 (age >= 65)
# Write a Boolean expression called getsDiscount that checks these rules.
# Test with: age = 10, age = 40, age = 70.

# %% [markdown]
# <section>
#   <h2>Learning Objectives</h2>
#   <p>Represent a list or string using a variable</p>
#
#   <h3>Essential Knowledge</h3>
#   <ul>
#     <li>A list is an ordered sequence of elements</li>
#     <li>An element is an individual value in a list</li>
#     <li>An index is a common method for referencing the elements in a list or string using natural numbers</li>
#     <li>A string is an ordered sequence of characters</li>
#   </ul>
# </section>
#
# <section>
#   <h2>New Types of Variables</h2>
#
#   <h3>Strings</h3>
#   <ul>
#     <li>An ordered sequence of characters</li>
#     <li>May contain letters, numbers, and all other special characters</li>
#     <li>Examples: words, phrases, sentences, ID numbers, etc.</li>
#   </ul>
#
#   <h3>Lists</h3>
#   <ul>
#     <li>An ordered sequence of elements</li>
#     <li>Each element is a variable</li>
#     <li>Examples: playlist of songs, names of students in a school/class, contacts in your phone, etc.</li>
#   </ul>
# </section>
#
# <section>
#   <h2>List Index</h2>
#   <ul>
#     <li>Each element of a string is referenced by an index</li>
#     <li>For purposes of the AP exam, the index starts at 1</li>
#     <li>Below is an example of a list with the appropriate indexes</li>
#   </ul>
# </section>
#
# <section>
#   <h2>Learning Objectives</h2>
#   <p>For data abstraction, develop data abstraction using lists to store multiple elements</p>
#
#   <h3>Essential Knowledge</h3>
#   <ul>
#     <li>Data abstraction provides a separation between the abstract properties of a data type and the concrete details of its representation</li>
#     <li>Data abstraction can be created using lists</li>
#     <li>The exam reference sheet provides notation for lists</li>
#     <li>
#       The exam reference sheet describes a list of structures whose index values are 1 through the number of elements in the list, inclusive.
#       For all list operations, if a list index is less than 1 or greater than the length of the list, an error message is produced and the program will terminate.
#     </li>
#   </ul>
# </section>
#
# <section>
#   <h2>Data Abstraction - Lists</h2>
#   <ul>
#     <li>Lists allow for data abstraction</li>
#     <li>Bundle variables together</li>
#     <li>Strings, numbers, characters, etc.</li>
#     <li>Give one name to a set of memory cells</li>
#     <li>Do not need to know how many variables will be needed</li>
#     <li>Do not need to know how the elements are stored together</li>
#   </ul>
# </section>
#
# <section>
#   <h2>Learning Objectives</h2>
#   <p>For data abstraction, explain how the use of data abstraction manages complexity in program code</p>
#
#   <h3>Essential Knowledge</h3>
#   <ul>
#     <li>Data abstractions manage complexity in programs by giving a collection of data without referencing the specific details of the representation</li>
#     <li>Developing a data abstraction to implement in a program can result in a program that is easier to develop and maintain</li>
#     <li>The use of lists allows multiple related items to be treated as a single value</li>
#     <li>The exam reference sheet provides notation for lists</li>
#     <li>
#       The exam reference sheet describes a list structure whose index values are 1 through the number of elements in the list, inclusive.
#       For all list operations, if a list index is less than 1 or greater than the length of the list,
#       an error message is produced and the program will terminate.
#     </li>
#   </ul>
# </section>
